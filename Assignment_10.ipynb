# %% [markdown]
# **Association Rules**

# %% [markdown]
# Data Preprocessing:

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("/content/Online retail.xlsx")

# %%
df
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7500 rows x 1 columns]

# %%
df.head()
# Out:
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
df.tail()
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt

# %%
df.shape
# Out:
# (7500, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                           --------------  -----
#  0   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil  7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB

# %%
df.describe()
# Out:
#        shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# count                                                7500
# unique                                               5175
# top                                               cookies
# freq                                                  223

# %%
df.columns
# Out:
# Index(['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil'], dtype='object')

# %%
# Handle missing values
df_cleaned = df.dropna()
print(df.isnull().sum())
# Out:
# shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil    0
# dtype: int64

# %%
# Remove duplicates
df_cleaned = df_cleaned.drop_duplicates()
print(df_cleaned)
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7492  burgers,salmon,pancakes,french fries,frozen sm...
# 7493  turkey,burgers,dessert wine,shrimp,pasta,tomat...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [5175 rows x 1 columns]

# %% [markdown]
# Association Rule Mining:

# %%
#convert the data into a list of transactions
transactions = [transaction.split(',') for transaction in df]

# %%
print(transactions[:5])
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']]

# %%
# One-hot encoding of the basket data
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
# Convert the array into a DataFrame
basket = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Display the first few rows of the basket
print(basket.head())
# Out:
#    almonds  antioxydant juice  avocado  cottage cheese  energy drink  \
# 0     True               True     True            True          True
#
#    frozen smoothie  green grapes  green tea  honey  low fat yogurt  \
# 0             True          True       True   True            True
#
#    mineral water  olive oil  salad  salmon  shrimp  spinach  tomato juice  \
# 0           True       True   True    True    True     True          True
#
#    vegetables mix  whole weat flour  yams
# 0            True              True  True

# %%
# Example transactions (replace this with your actual transaction data)
transactions = [
    ['milk', 'bread', 'butter'],
    ['bread', 'butter', 'jam'],
    ['milk', 'bread'],
]

# Initialize TransactionEncoder
te = TransactionEncoder()

# Transform transactions into a one-hot encoded array
te_ary = te.fit(transactions).transform(transactions)

# Convert the array into a DataFrame
basket = pd.DataFrame(te_ary, columns=te.columns_)

# Check if `basket` is defined and properly structured
print(basket.head())
# Out:
#    bread  butter    jam   milk
# 0   True    True  False   True
# 1   True    True   True  False
# 2   True   False  False   True

# %%
# Apriori Algorithm
# Set minimum support threshold
min_support = 0.01  # Adjust this threshold as needed
print(min_support)
# Out:
# 0.01

# %%
# Generate frequent itemsets
frequent_itemsets = apriori(basket, min_support=min_support, use_colnames=True)
print(frequent_itemsets)
# Out:
#      support               itemsets
# 0   1.000000                (bread)
# 1   0.666667               (butter)
# 2   0.333333                  (jam)
# 3   0.666667                 (milk)
# 4   0.666667        (butter, bread)
# 5   0.333333           (jam, bread)
# 6   0.666667          (milk, bread)
# 7   0.333333          (jam, butter)
# 8   0.333333         (butter, milk)
# 9   0.333333   (jam, butter, bread)
# 10  0.333333  (butter, milk, bread)

# %%
# Association Rule Mining
# Set minimum confidence and lift thresholds
min_confidence = 0.2  # Adjust this threshold as needed
min_lift = 1.0      # Adjust this threshold as needed
print(min_confidence)
print(min_lift)
# Out:
# 0.2
# 1.0

# %%
 #Calculate the number of frequent itemsets
num_itemsets = len(frequent_itemsets)

# Generate the association rules with 'num_itemsets'
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0, num_itemsets=num_itemsets)

# Display the rules
print(rules.head())
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0    (butter)     (bread)            0.666667            1.000000  0.666667
# 1     (bread)    (butter)            1.000000            0.666667  0.666667
# 2       (jam)     (bread)            0.333333            1.000000  0.333333
# 3     (bread)       (jam)            1.000000            0.333333  0.333333
# 4      (milk)     (bread)            0.666667            1.000000  0.666667
#
#    confidence  lift  representativity  leverage  conviction  zhangs_metric  \
# 0    1.000000   1.0               1.0       0.0         inf            0.0
# 1    0.666667   1.0               1.0       0.0         1.0            0.0
# 2    1.000000   1.0               1.0       0.0         inf            0.0
# 3    0.333333   1.0               1.0       0.0         1.0            0.0
# 4    1.000000   1.0               1.0       0.0         inf            0.0
#
#     jaccard  certainty  kulczynski
# 0  0.666667        0.0    0.833333
# 1  0.666667        0.0    0.833333
# 2  0.333333        0.0    0.666667
# 3  0.333333        0.0    0.666667
# 4  0.666667        0.0    0.833333

# %%
# Filter rules based on lift
filtered_rules = rules[rules['lift'] >= min_lift]
print(filtered_rules)
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0          (butter)          (bread)            0.666667            1.000000
# 1           (bread)         (butter)            1.000000            0.666667
# 2             (jam)          (bread)            0.333333            1.000000
# 3           (bread)            (jam)            1.000000            0.333333
# 4            (milk)          (bread)            0.666667            1.000000
# 5           (bread)           (milk)            1.000000            0.666667
# 6             (jam)         (butter)            0.333333            0.666667
# 7          (butter)            (jam)            0.666667            0.333333
# 8     (jam, butter)          (bread)            0.333333            1.000000
# 9      (jam, bread)         (butter)            0.333333            0.666667
# 10  (butter, bread)            (jam)            0.666667            0.333333
# 11            (jam)  (butter, bread)            0.333333            0.666667
# 12         (butter)     (jam, bread)            0.666667            0.333333
# 13          (bread)    (jam, butter)            1.000000            0.333333
# 14   (butter, milk)          (bread)            0.333333            1.000000
# 15          (bread)   (butter, milk)            1.000000            0.333333
#
#      support  confidence  lift  representativity  leverage  conviction  \
# 0   0.666667    1.000000   1.0               1.0  0.000000         inf
# 1   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 2   0.333333    1.000000   1.0               1.0  0.000000         inf
# 3   0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 4   0.666667    1.000000   1.0               1.0  0.000000         inf
# 5   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 6   0.333333    1.000000   1.5               1.0  0.111111         inf
# 7   0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 8   0.333333    1.000000   1.0               1.0  0.000000         inf
# 9   0.333333    1.000000   1.5               1.0  0.111111         inf
# 10  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 11  0.333333    1.000000   1.5               1.0  0.111111         inf
# 12  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 13  0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 14  0.333333    1.000000   1.0               1.0  0.000000         inf
# 15  0.333333    0.333333   1.0               1.0  0.000000    1.000000
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0             0.0  0.666667       0.00    0.833333
# 1             0.0  0.666667       0.00    0.833333
# 2             0.0  0.333333       0.00    0.666667
# 3             0.0  0.333333       0.00    0.666667
# 4             0.0  0.666667       0.00    0.833333
# 5             0.0  0.666667       0.00    0.833333
# 6             0.5  0.500000       1.00    0.750000
# 7             1.0  0.500000       0.25    0.750000
# 8             0.0  0.333333       0.00    0.666667
# 9             0.5  0.500000       1.00    0.750000
# 10            1.0  0.500000       0.25    0.750000
# 11            0.5  0.500000       1.00    0.750000
# 12            1.0  0.500000       0.25    0.750000
# 13            0.0  0.333333       0.00    0.666667
# 14            0.0  0.333333       0.00    0.666667
# 15            0.0  0.333333       0.00    0.666667

# %%
# Display the frequent itemsets and association rules
print("Frequent Itemsets:\n", frequent_itemsets)
print("\nAssociation Rules:\n", filtered_rules)
# Out:
# Frequent Itemsets:
#       support               itemsets
# 0   1.000000                (bread)
# 1   0.666667               (butter)
# 2   0.333333                  (jam)
# 3   0.666667                 (milk)
# 4   0.666667        (butter, bread)
# 5   0.333333           (jam, bread)
# 6   0.666667          (milk, bread)
# 7   0.333333          (jam, butter)
# 8   0.333333         (butter, milk)
# 9   0.333333   (jam, butter, bread)
# 10  0.333333  (butter, milk, bread)
#
# Association Rules:
#          antecedents      consequents  antecedent support  consequent support  \
# 0          (butter)          (bread)            0.666667            1.000000
# 1           (bread)         (butter)            1.000000            0.666667
# 2             (jam)          (bread)            0.333333            1.000000
# 3           (bread)            (jam)            1.000000            0.333333
# 4            (milk)          (bread)            0.666667            1.000000
# 5           (bread)           (milk)            1.000000            0.666667
# 6             (jam)         (butter)            0.333333            0.666667
# 7          (butter)            (jam)            0.666667            0.333333
# 8     (jam, butter)          (bread)            0.333333            1.000000
# 9      (jam, bread)         (butter)            0.333333            0.666667
# 10  (butter, bread)            (jam)            0.666667            0.333333
# 11            (jam)  (butter, bread)            0.333333            0.666667
# 12         (butter)     (jam, bread)            0.666667            0.333333
# 13          (bread)    (jam, butter)            1.000000            0.333333
# 14   (butter, milk)          (bread)            0.333333            1.000000
# 15          (bread)   (butter, milk)            1.000000            0.333333
#
#      support  confidence  lift  representativity  leverage  conviction  \
# 0   0.666667    1.000000   1.0               1.0  0.000000         inf
# 1   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 2   0.333333    1.000000   1.0               1.0  0.000000         inf
# 3   0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 4   0.666667    1.000000   1.0               1.0  0.000000         inf
# 5   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 6   0.333333    1.000000   1.5               1.0  0.111111         inf
# 7   0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 8   0.333333    1.000000   1.0               1.0  0.000000         inf
# 9   0.333333    1.000000   1.5               1.0  0.111111         inf
# 10  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 11  0.333333    1.000000   1.5               1.0  0.111111         inf
# 12  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 13  0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 14  0.333333    1.000000   1.0               1.0  0.000000         inf
# 15  0.333333    0.333333   1.0               1.0  0.000000    1.000000
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0             0.0  0.666667       0.00    0.833333
# 1             0.0  0.666667       0.00    0.833333
# 2             0.0  0.333333       0.00    0.666667
# 3             0.0  0.333333       0.00    0.666667
# 4             0.0  0.666667       0.00    0.833333
# 5             0.0  0.666667       0.00    0.833333
# 6             0.5  0.500000       1.00    0.750000
# 7             1.0  0.500000       0.25    0.750000
# 8             0.0  0.333333       0.00    0.666667
# 9             0.5  0.500000       1.00    0.750000
# 10            1.0  0.500000       0.25    0.750000
# 11            0.5  0.500000       1.00    0.750000
# 12            1.0  0.500000       0.25    0.750000
# 13            0.0  0.333333       0.00    0.666667
# 14            0.0  0.333333       0.00    0.666667
# 15            0.0  0.333333       0.00    0.666667

# %%
# Analyzing and Interpreting Results
print("\nAssociation rules sorted by lift:\n", filtered_rules.sort_values('lift', ascending=False))

print("\nAssociation rules sorted by confidence:\n", filtered_rules.sort_values('confidence', ascending=False))
# Out:
# Association rules sorted by lift:
#          antecedents      consequents  antecedent support  consequent support  \
# 6             (jam)         (butter)            0.333333            0.666667
# 7          (butter)            (jam)            0.666667            0.333333
# 9      (jam, bread)         (butter)            0.333333            0.666667
# 10  (butter, bread)            (jam)            0.666667            0.333333
# 11            (jam)  (butter, bread)            0.333333            0.666667
# 12         (butter)     (jam, bread)            0.666667            0.333333
# 0          (butter)          (bread)            0.666667            1.000000
# 1           (bread)         (butter)            1.000000            0.666667
# 2             (jam)          (bread)            0.333333            1.000000
# 3           (bread)            (jam)            1.000000            0.333333
# 4            (milk)          (bread)            0.666667            1.000000
# 5           (bread)           (milk)            1.000000            0.666667
# 8     (jam, butter)          (bread)            0.333333            1.000000
# 13          (bread)    (jam, butter)            1.000000            0.333333
# 14   (butter, milk)          (bread)            0.333333            1.000000
# 15          (bread)   (butter, milk)            1.000000            0.333333
#
#      support  confidence  lift  representativity  leverage  conviction  \
# 6   0.333333    1.000000   1.5               1.0  0.111111         inf
# 7   0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 9   0.333333    1.000000   1.5               1.0  0.111111         inf
# 10  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 11  0.333333    1.000000   1.5               1.0  0.111111         inf
# 12  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 0   0.666667    1.000000   1.0               1.0  0.000000         inf
# 1   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 2   0.333333    1.000000   1.0               1.0  0.000000         inf
# 3   0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 4   0.666667    1.000000   1.0               1.0  0.000000         inf
# 5   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 8   0.333333    1.000000   1.0               1.0  0.000000         inf
# 13  0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 14  0.333333    1.000000   1.0               1.0  0.000000         inf
# 15  0.333333    0.333333   1.0               1.0  0.000000    1.000000
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 6             0.5  0.500000       1.00    0.750000
# 7             1.0  0.500000       0.25    0.750000
# 9             0.5  0.500000       1.00    0.750000
# 10            1.0  0.500000       0.25    0.750000
# 11            0.5  0.500000       1.00    0.750000
# 12            1.0  0.500000       0.25    0.750000
# 0             0.0  0.666667       0.00    0.833333
# 1             0.0  0.666667       0.00    0.833333
# 2             0.0  0.333333       0.00    0.666667
# 3             0.0  0.333333       0.00    0.666667
# 4             0.0  0.666667       0.00    0.833333
# 5             0.0  0.666667       0.00    0.833333
# 8             0.0  0.333333       0.00    0.666667
# 13            0.0  0.333333       0.00    0.666667
# 14            0.0  0.333333       0.00    0.666667
# 15            0.0  0.333333       0.00    0.666667
#
# Association rules sorted by confidence:
#          antecedents      consequents  antecedent support  consequent support  \
# 0          (butter)          (bread)            0.666667            1.000000
# 2             (jam)          (bread)            0.333333            1.000000
# 4            (milk)          (bread)            0.666667            1.000000
# 6             (jam)         (butter)            0.333333            0.666667
# 8     (jam, butter)          (bread)            0.333333            1.000000
# 9      (jam, bread)         (butter)            0.333333            0.666667
# 11            (jam)  (butter, bread)            0.333333            0.666667
# 14   (butter, milk)          (bread)            0.333333            1.000000
# 1           (bread)         (butter)            1.000000            0.666667
# 5           (bread)           (milk)            1.000000            0.666667
# 7          (butter)            (jam)            0.666667            0.333333
# 10  (butter, bread)            (jam)            0.666667            0.333333
# 12         (butter)     (jam, bread)            0.666667            0.333333
# 3           (bread)            (jam)            1.000000            0.333333
# 13          (bread)    (jam, butter)            1.000000            0.333333
# 15          (bread)   (butter, milk)            1.000000            0.333333
#
#      support  confidence  lift  representativity  leverage  conviction  \
# 0   0.666667    1.000000   1.0               1.0  0.000000         inf
# 2   0.333333    1.000000   1.0               1.0  0.000000         inf
# 4   0.666667    1.000000   1.0               1.0  0.000000         inf
# 6   0.333333    1.000000   1.5               1.0  0.111111         inf
# 8   0.333333    1.000000   1.0               1.0  0.000000         inf
# 9   0.333333    1.000000   1.5               1.0  0.111111         inf
# 11  0.333333    1.000000   1.5               1.0  0.111111         inf
# 14  0.333333    1.000000   1.0               1.0  0.000000         inf
# 1   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 5   0.666667    0.666667   1.0               1.0  0.000000    1.000000
# 7   0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 10  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 12  0.333333    0.500000   1.5               1.0  0.111111    1.333333
# 3   0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 13  0.333333    0.333333   1.0               1.0  0.000000    1.000000
# 15  0.333333    0.333333   1.0               1.0  0.000000    1.000000
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0             0.0  0.666667       0.00    0.833333
# 2             0.0  0.333333       0.00    0.666667
# 4             0.0  0.666667       0.00    0.833333
# 6             0.5  0.500000       1.00    0.750000
# 8             0.0  0.333333       0.00    0.666667
# 9             0.5  0.500000       1.00    0.750000
# 11            0.5  0.500000       1.00    0.750000
# 14            0.0  0.333333       0.00    0.666667
# 1             0.0  0.666667       0.00    0.833333
# 5             0.0  0.666667       0.00    0.833333
# 7             1.0  0.500000       0.25    0.750000
# 10            1.0  0.500000       0.25    0.750000
# 12            1.0  0.500000       0.25    0.750000
# 3             0.0  0.333333       0.00    0.666667
# 13            0.0  0.333333       0.00    0.666667
# 15            0.0  0.333333       0.00    0.666667

# %% [markdown]
# **Analysis and Interpretation:**

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Sample Transaction Dataset
# Replace this with your actual dataset
data = {
    'Milk': [1, 0, 1, 1, 0],
    'Bread': [1, 1, 1, 0, 0],
    'Butter': [0, 1, 1, 0, 1],
    'Eggs': [1, 1, 0, 0, 1],
    'Cheese': [0, 0, 1, 1, 1]
}

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# %%
# Step 1: Generate frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)

# %%
# Step 2: Generate association rules
# Calculate the number of frequent itemsets
num_itemsets = len(frequent_itemsets)

# Generate the association rules with 'num_itemsets'
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0, num_itemsets=num_itemsets)

# Display the rules
print(rules.head())
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Bread)      (Milk)                 0.6                 0.6      0.4
# 1      (Milk)     (Bread)                 0.6                 0.6      0.4
# 2    (Cheese)      (Milk)                 0.6                 0.6      0.4
# 3      (Milk)    (Cheese)                 0.6                 0.6      0.4
# 4     (Bread)    (Butter)                 0.6                 0.6      0.4
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.666667  1.111111               1.0      0.04         1.2
# 1    0.666667  1.111111               1.0      0.04         1.2
# 2    0.666667  1.111111               1.0      0.04         1.2
# 3    0.666667  1.111111               1.0      0.04         1.2
# 4    0.666667  1.111111               1.0      0.04         1.2
#
#    zhangs_metric  jaccard  certainty  kulczynski
# 0           0.25      0.5   0.166667    0.666667
# 1           0.25      0.5   0.166667    0.666667
# 2           0.25      0.5   0.166667    0.666667
# 3           0.25      0.5   0.166667    0.666667
# 4           0.25      0.5   0.166667    0.666667

# %%
# Step 3: Display the results
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#     support                       itemsets
# 0       0.6                         (Milk)
# 1       0.6                        (Bread)
# 2       0.6                       (Butter)
# 3       0.6                         (Eggs)
# 4       0.6                       (Cheese)
# 5       0.4                  (Bread, Milk)
# 6       0.2                 (Butter, Milk)
# 7       0.2                   (Eggs, Milk)
# 8       0.4                 (Cheese, Milk)
# 9       0.4                (Bread, Butter)
# 10      0.4                  (Bread, Eggs)
# 11      0.2                (Cheese, Bread)
# 12      0.4                 (Butter, Eggs)
# 13      0.4               (Cheese, Butter)
# 14      0.2                 (Cheese, Eggs)
# 15      0.2          (Bread, Butter, Milk)
# 16      0.2            (Bread, Eggs, Milk)
# 17      0.2          (Cheese, Bread, Milk)
# 18      0.2         (Cheese, Butter, Milk)
# 19      0.2          (Bread, Butter, Eggs)
# 20      0.2        (Cheese, Bread, Butter)
# 21      0.2         (Cheese, Butter, Eggs)
# 22      0.2  (Cheese, Bread, Butter, Milk)
#
# Association Rules:
#                 antecedents              consequents  antecedent support  \
# 0                   (Bread)                   (Milk)                 0.6
# 1                    (Milk)                  (Bread)                 0.6
# 2                  (Cheese)                   (Milk)                 0.6
# 3                    (Milk)                 (Cheese)                 0.6
# 4                   (Bread)                 (Butter)                 0.6
# 5                  (Butter)                  (Bread)                 0.6
# 6                   (Bread)                   (Eggs)                 0.6
# 7                    (Eggs)                  (Bread)                 0.6
# 8                  (Butter)                   (Eggs)                 0.6
# 9                    (Eggs)                 (Butter)                 0.6
# 10                 (Cheese)                 (Butter)                 0.6
# 11                 (Butter)                 (Cheese)                 0.6
# 12           (Butter, Milk)                  (Bread)                 0.2
# 13                  (Bread)           (Butter, Milk)                 0.6
# 14             (Eggs, Milk)                  (Bread)                 0.2
# 15                  (Bread)             (Eggs, Milk)                 0.6
# 16          (Cheese, Bread)                   (Milk)                 0.2
# 17                   (Milk)          (Cheese, Bread)                 0.6
# 18           (Butter, Milk)                 (Cheese)                 0.2
# 19                 (Cheese)           (Butter, Milk)                 0.6
# 20          (Cheese, Bread)                 (Butter)                 0.2
# 21                 (Butter)          (Cheese, Bread)                 0.6
# 22           (Cheese, Eggs)                 (Butter)                 0.2
# 23                 (Butter)           (Cheese, Eggs)                 0.6
# 24  (Cheese, Bread, Butter)                   (Milk)                 0.2
# 25    (Cheese, Bread, Milk)                 (Butter)                 0.2
# 26   (Cheese, Butter, Milk)                  (Bread)                 0.2
# 27    (Bread, Butter, Milk)                 (Cheese)                 0.2
# 28          (Cheese, Bread)           (Butter, Milk)                 0.2
# 29         (Cheese, Butter)            (Bread, Milk)                 0.4
# 30           (Cheese, Milk)          (Bread, Butter)                 0.4
# 31          (Bread, Butter)           (Cheese, Milk)                 0.4
# 32            (Bread, Milk)         (Cheese, Butter)                 0.4
# 33           (Butter, Milk)          (Cheese, Bread)                 0.2
# 34                 (Cheese)    (Bread, Butter, Milk)                 0.6
# 35                  (Bread)   (Cheese, Butter, Milk)                 0.6
# 36                 (Butter)    (Cheese, Bread, Milk)                 0.6
# 37                   (Milk)  (Cheese, Bread, Butter)                 0.6
#
#     consequent support  support  confidence      lift  representativity  \
# 0                  0.6      0.4    0.666667  1.111111               1.0
# 1                  0.6      0.4    0.666667  1.111111               1.0
# 2                  0.6      0.4    0.666667  1.111111               1.0
# 3                  0.6      0.4    0.666667  1.111111               1.0
# 4                  0.6      0.4    0.666667  1.111111               1.0
# 5                  0.6      0.4    0.666667  1.111111               1.0
# 6                  0.6      0.4    0.666667  1.111111               1.0
# 7                  0.6      0.4    0.666667  1.111111               1.0
# 8                  0.6      0.4    0.666667  1.111111               1.0
# 9                  0.6      0.4    0.666667  1.111111               1.0
# 10                 0.6      0.4    0.666667  1.111111               1.0
# 11                 0.6      0.4    0.666667  1.111111               1.0
# 12                 0.6      0.2    1.000000  1.666667               1.0
# 13                 0.2      0.2    0.333333  1.666667               1.0
# 14                 0.6      0.2    1.000000  1.666667               1.0
# 15                 0.2      0.2    0.333333  1.666667               1.0
# 16                 0.6      0.2    1.000000  1.666667               1.0
# 17                 0.2      0.2    0.333333  1.666667               1.0
# 18                 0.6      0.2    1.000000  1.666667               1.0
# 19                 0.2      0.2    0.333333  1.666667               1.0
# 20                 0.6      0.2    1.000000  1.666667               1.0
# 21                 0.2      0.2    0.333333  1.666667               1.0
# 22                 0.6      0.2    1.000000  1.666667               1.0
# 23                 0.2      0.2    0.333333  1.666667               1.0
# 24                 0.6      0.2    1.000000  1.666667               1.0
# 25                 0.6      0.2    1.000000  1.666667               1.0
# 26                 0.6      0.2    1.000000  1.666667               1.0
# 27                 0.6      0.2    1.000000  1.666667               1.0
# 28                 0.2      0.2    1.000000  5.000000               1.0
# 29                 0.4      0.2    0.500000  1.250000               1.0
# 30                 0.4      0.2    0.500000  1.250000               1.0
# 31                 0.4      0.2    0.500000  1.250000               1.0
# 32                 0.4      0.2    0.500000  1.250000               1.0
# 33                 0.2      0.2    1.000000  5.000000               1.0
# 34                 0.2      0.2    0.333333  1.666667               1.0
# 35                 0.2      0.2    0.333333  1.666667               1.0
# 36                 0.2      0.2    0.333333  1.666667               1.0
# 37                 0.2      0.2    0.333333  1.666667               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 1       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 2       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 3       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 4       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 5       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 6       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 7       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 8       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 9       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 10      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 11      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 12      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 13      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 14      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 15      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 16      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 17      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 18      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 19      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 20      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 21      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 22      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 23      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 24      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 25      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 26      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 27      0.08         inf       0.500000  0.333333   1.000000    0.666667
# 28      0.16         inf       1.000000  1.000000   1.000000    1.000000
# 29      0.04         1.2       0.333333  0.333333   0.166667    0.500000
# 30      0.04         1.2       0.333333  0.333333   0.166667    0.500000
# 31      0.04         1.2       0.333333  0.333333   0.166667    0.500000
# 32      0.04         1.2       0.333333  0.333333   0.166667    0.500000
# 33      0.16         inf       1.000000  1.000000   1.000000    1.000000
# 34      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 35      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 36      0.08         1.2       1.000000  0.333333   0.166667    0.666667
# 37      0.08         1.2       1.000000  0.333333   0.166667    0.666667

# %%
# Step 4: Analyze the results
# Example: Sort rules by lift
sorted_rules = rules.sort_values(by='lift', ascending=False)
print("\nTop Association Rules (by Lift):")
print(sorted_rules.head())
# Out:
# Top Association Rules (by Lift):
#         antecedents            consequents  antecedent support  \
# 33   (Butter, Milk)        (Cheese, Bread)                 0.2
# 28  (Cheese, Bread)         (Butter, Milk)                 0.2
# 19         (Cheese)         (Butter, Milk)                 0.6
# 17           (Milk)        (Cheese, Bread)                 0.6
# 36         (Butter)  (Cheese, Bread, Milk)                 0.6
#
#     consequent support  support  confidence      lift  representativity  \
# 33                 0.2      0.2    1.000000  5.000000               1.0
# 28                 0.2      0.2    1.000000  5.000000               1.0
# 19                 0.2      0.2    0.333333  1.666667               1.0
# 17                 0.2      0.2    0.333333  1.666667               1.0
# 36                 0.2      0.2    0.333333  1.666667               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 33      0.16         inf            1.0  1.000000   1.000000    1.000000
# 28      0.16         inf            1.0  1.000000   1.000000    1.000000
# 19      0.08         1.2            1.0  0.333333   0.166667    0.666667
# 17      0.08         1.2            1.0  0.333333   0.166667    0.666667
# 36      0.08         1.2            1.0  0.333333   0.166667    0.666667

# %% [markdown]
# **Interview Questions:**

# %% [markdown]
# 1.What is lift and why is it important in Association rules?
#
# Lift is a metric used in association rule mining to measure the strength of the relationship between two items 𝐴A and 𝐵 B compared to their expected co-occurrence if they were independent. It quantifies how much more likely items 𝐴A and 𝐵 B are to appear together than would be expected if they were unrelated.
#
# Formula for Lift:
#
# Lift(A→B)= Support(A∩B)/Support(A)×Support(B)
#
# Key: Lift > 1 means 𝐴 A and 𝐵 B are positively associated

# %% [markdown]
# 2.What is support and Confidence. How do you calculate them?
#
# Support:
#
# Support measures how frequently an itemset appears in the dataset.
#
# Formula:
#
# Support(𝐴)=Frequency of transactions containing 𝐴 /Total number of transactions
#
# It represents the proportion of transactions in which the itemset occurs. Higher support means the rule is more applicable across the dataset.
#
# Confidence:
#
# Confidence measures how often 𝐵 B appears in transactions containing 𝐴A.
#
# Formula:
#
# Confidence(A→B)= Support(A)/Support(A∩B)
#
# It reflects the reliability of the rule 𝐴→𝐵 A→B by showing the percentage of transactions with 𝐴 A that also include 𝐵B.

# %% [markdown]
#  3.What are some limitations or challenges of Association rules mining?
# 1.Too Many Rules: Hard to find useful ones.
# 2.Computational Cost: Large datasets are slow to process.
# 3.Sparse Data: Low support for many itemsets.
# 4.Threshold Issues: Subjective support/confidence limits.
# 5.Correlation, Not Causation: Shows relationships, not reasons.
# 6.No Time Factor: Ignores sequence/order of events.
# 7.High Dimensionality: Too many itemsets to handle.
